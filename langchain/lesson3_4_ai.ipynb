# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in c:\users\user\.conda\envs\langchain\lib\site-packages (0.5.3)
# Requirement already satisfied: httpx>=0.27 in c:\users\user\.conda\envs\langchain\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in c:\users\user\.conda\envs\langchain\lib\site-packages (from ollama) (2.11.8)
# Requirement already satisfied: anyio in c:\users\user\.conda\envs\langchain\lib\site-packages (from httpx>=0.27->ollama) (4.10.0)
# Requirement already satisfied: certifi in c:\users\user\.conda\envs\langchain\lib\site-packages (from httpx>=0.27->ollama) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\user\.conda\envs\langchain\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in c:\users\user\.conda\envs\langchain\lib\site-packages (from httpx>=0.27->ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\user\.conda\envs\langchain\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\.conda\envs\langchain\lib\site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\.conda\envs\langchain\lib\site-packages (from pydantic>=2.9->ollama) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\user\.conda\envs\langchain\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\.conda\envs\langchain\lib\site-packages (from pydantic>=2.9->ollama) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\.conda\envs\langchain\lib\site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#使用ollam的api
from ollama import chat
from ollama import ChatResponse
response: ChatResponse = chat(model='llama3.2:3b', messages=[
  {
    'role': 'user',
    'content': '=天空為什麼是藍色的?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# 天空是藍色的原因，主要是由於地球的大氣層中含有一種叫做氧化氫（N2O）的氣體，這種氣體當陽光與它相遇時，會發生Photochemical反應，產生一種蓝色顏色的光。
# 天空是藍色的原因，主要是由於地球的大氣層中含有一種叫做氧化氫（N2O）的氣體，這種氣體當陽光與它相遇時，會發生Photochemical反應，產生一種蓝色顏色的光。

# %%
import requests
import json

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gemma3:1b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        },
        "max_tokens": 100,
        "format": "json",
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gemma3:1b', 'created_at': '2025-09-13T07:55:13.9263909Z', 'response': '{ \n    "解釋：":\n    "Python的函式就像是小工具，你可以用它們來做一些事情。你可以把這些小工具叫做函式。 就像你用工具來完成任務一樣，Python的函式也幫你完成程式碼。",\n    "簡單來說：":" 確保有簡單的例子。 例子說明。 簡單說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 1 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 ', 'done': False}
# {
#     "解釋：":
#     "Python的函式就像是小工具，你可以用它們來做一些事情。你可以把這些小工具叫做函式。 就像你用工具來完成任務一樣，Python的函式也幫你完成程式碼。",
#     "簡單來說：":" 確保有簡單的例子。 例子說明。 簡單說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明。 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明। 例子說明。 例子說明। 例子說明। 例子說明。 例子說明。 例子說明। 例子說明。 例子說明。 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明। 例子說明。 例子說明。 1

# %%
import requests

def chat_with_ollama(prompt: str):
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "gpt-oss:20b",
        "prompt": prompt,
        "stream": False,
        "options": { #參考說明1
            "temperature": 0.7,
            "top_p": 0.9,
            "top_k": 50,
        },
        "max_tokens": 100,
        "format": "json",
    }

    response = requests.post(url, json=payload)
    result = response.json()
    print("💬 AI 回應：")
    # Print the whole result for debugging
    print(result)
    # Try to print the 'response' key if it exists, otherwise print possible keys
    if "response" in result:
        print(result["response"])
    elif "message" in result:
        print(result["message"])
    elif "content" in result:
        print(result["content"])
    else:
        print("No expected key found in response. Available keys:", result.keys())

#範例輸入
chat_with_ollama("請用簡單的方式解釋什麼是Python的函式？")
# Out:
# 💬 AI 回應：
# {'model': 'gpt-oss:20b', 'created_at': '2025-09-13T07:57:28.9840034Z', 'response': 'The user says: ": "請用簡單的方式解釋什麼是Python的函式？" \n  \t\t\n  \t\t\n  \t\t\n  \t\t\n \t\t\n \t\t\n \t\t\n \t\t\n \t\t\n \t\t\n \t\t\n \t\t\n \t\t\n', 'done': False}
# The user says: ": "請用簡單的方式解釋什麼是Python的函式？"
