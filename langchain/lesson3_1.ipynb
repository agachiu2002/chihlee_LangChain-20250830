# %%
# 使用python內建的標準函式庫,建立範例
# 這裡我們將示範如何使用 Python 內建的標準函式庫（例如 datetime、random、os）
import datetime
import random
import os

# 範例1：使用 datetime 取得現在的日期和時間
now = datetime.datetime.now()
print("現在的日期和時間：", now)

# 範例2：使用 random 產生 1 到 10 之間的隨機整數
rand_num = random.randint(1, 10)
print("隨機產生的數字：", rand_num)

# 範例3：使用 os 取得目前的工作目錄
current_dir = os.getcwd()
print("目前的工作目錄：", current_dir)
# Out:
# 現在的日期和時間： 2025-09-13 12:05:09.675026
# 隨機產生的數字： 2
# 目前的工作目錄： c:\Users\user\Documents\GitHub\chihlee_LangChain-20250830\langchain

# %%
pip --version
# Out:
# pip 25.2 from c:\Users\user\.conda\envs\langchain\Lib\site-packages\pip (python 3.11)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\user\.conda\envs\langchain\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\.conda\envs\langchain\lib\site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\.conda\envs\langchain\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\.conda\envs\langchain\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\.conda\envs\langchain\lib\site-packages (from requests) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
response = requests.get("http://www.google.com")
print("回應的狀態碼:" ,response.status_code)
print("回應的前100個字元:", response.text[:100])
# Out:
# 回應的狀態碼: 200
# 回應的前100個字元: <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="zh-TW"><head><meta cont
