# %% [markdown]
# <a href="https://colab.research.google.com/github/agachiu2002/chihlee_LangChain-20250830/blob/main/lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello! python!")
# Out:
# hello! python!
