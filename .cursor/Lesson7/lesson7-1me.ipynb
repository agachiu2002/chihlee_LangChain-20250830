# %%
import os 
from langchain_community.document_loaders import TextLoader 
current_dir = os.path.dirname(os.path.abspath("_file_"))
file_path =os.path.join(current_dir, "books","智慧型手機使用手冊.txt")
persistent_directory = os.path.join(current_dir, "db", "chroma_db_v3")
try:
        if not os.path.exists(persistent_directory):
            if not os.path.exists(file_path):
                raise FileNotFoundError (
                    f"檔案 {file_path} 不存在，請檢查路徑是否正確"
                )
            print("檔案正常")
        else:
            print("向量資料庫已經存在，不需要初始化")
except Exception as error:
    print(error)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 2
#       1 import os
# ----> 2 from langchain_community.document_loaders import TextLoader
#       3 current_dir = os.path.dirname(os.path.abspath("_file_"))
#       4 file_path =os.path.join(current_dir, "books","智慧型手機使用手冊.txt")
#
# ModuleNotFoundError: No module named 'langchain_community'
