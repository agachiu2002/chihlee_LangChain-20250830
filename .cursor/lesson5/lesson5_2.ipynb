# %%
import gradio as gr

def greet(name, intensity):
    return "Hello, " + name + "!" * int(intensity)

demo = gr.Interface(
    fn=greet,
    inputs=["text", "slider"],
    outputs=["text"],
    examples = [["徐國堂", 2],["徐瑞彤", 1]]
)
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from langchain_ollama import ChatOllama
import gradio as gr
from dotenv import load_dotenv
import os

# 載入環境變數（可用 OLLAMA_URL / OLLAMA_MODEL 覆蓋預設）
load_dotenv()
#OLLAMA_URL = os.getenv("OLLAMA_URL", "http://localhost:11434")
#MODEL_NAME = os.getenv("OLLAMA_MODEL", "llama3.2:latest")

# 使用最原始的呼叫方式：直接以字串 prompt 送到 Ollama
model = ChatOllama(model="gemma3:1b", base_url="http://localhost:11434")


def answer(prompt: str) -> str:
    """最簡單的 wrapper：把 prompt 傳給 model.invoke，回傳文字回應。"""
    if not prompt:
        return ""
    res = model.invoke(prompt)
    return res.content if hasattr(res, "content") else str(res)
    #


# 最小的 Gradio 介面：一個輸入框 + 一個文字輸出
iface = gr.Interface(
    fn=answer,
    inputs=gr.Textbox(lines=3, placeholder="在此輸入問題，按送出..."),
    outputs="text",
    title="Ollama 簡易 Gradio 範例",
    description="示範如何把原先的 Ollama 呼叫整合到 Gradio。可用 OLLAMA_URL/OLLAMA_MODEL 環境變數覆蓋預設。",
)

if __name__ == "__main__":
    iface.launch(server_name="127.0.0.1", server_port=7862, share=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 34
#      25 iface = gr.Interface(
#      26     fn=answer,
#      27     inputs=gr.Textbox(lines=3, placeholder="在此輸入問題，按送出..."),
#    (...)
#      30     description="示範如何把原先的 Ollama 呼叫整合到 Gradio。可用 OLLAMA_URL/OLLAMA_MODEL 環境變數覆蓋預設。",
#      31 )
#      33 if __name__ == "__main__":
# ---> 34     iface.launch(server_name="127.0.0.1", server_port=7862, share=True)
#
# File c:\Users\user\Documents\GitHub\chihlee_LangChain-20250830\.venv\lib\site-packages\gradio\blocks.py:2635, in Blocks.launch(self, inline, inbrowser, share, debug, max_threads, auth, auth_message, prevent_thread_lock, show_error, server_name, server_port, height, width, favicon_path, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_verify, quiet, show_api, allowed_paths, blocked_paths, root_path, app_kwargs, state_session_capacity, share_server_address, share_server_protocol, share_server_tls_certificate, auth_dependency, max_file_size, enable_monitoring, strict_cors, node_server_name, node_port, ssr_mode, pwa, mcp_server, _frontend, i18n)
#    2627 else:
#    2628     from gradio import http_server
#    2630     (
#    2631         server_name,
#    2632         server_port,
#    2633         local_url,
#    2634         server,
# -> 2635     ) = http_server.start_server(
#    2636         app=self.app,
#    2637         server_name=server_name,
#    2638         server_port=server_port,
#    2639         ssl_keyfile=ssl_keyfile,
#    2640         ssl_certfile=ssl_certfile,
#    2641         ssl_keyfile_password=ssl_keyfile_password,
#    2642     )
#    2643     self.server_name = server_name
#    2644     self.local_url = local_url
#
# File c:\Users\user\Documents\GitHub\chihlee_LangChain-20250830\.venv\lib\site-packages\gradio\http_server.py:157, in start_server(app, server_name, server_port, ssl_keyfile, ssl_certfile, ssl_keyfile_password)
#     155         pass
#     156 else:
# --> 157     raise OSError(
#     158         f"Cannot find empty port in range: {min(server_ports)}-{max(server_ports)}. You can specify a different port by setting the GRADIO_SERVER_PORT environment variable or passing the `server_port` parameter to `launch()`."
#     159     )
#     161 if ssl_keyfile is not None:
#     162     path_to_local_server = f"https://{url_host_name}:{port}/"
#
# OSError: Cannot find empty port in range: 7862-7862. You can specify a different port by setting the GRADIO_SERVER_PORT environment variable or passing the `server_port` parameter to `launch()`.
