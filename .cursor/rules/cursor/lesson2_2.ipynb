# %%
is_nice:bool = False
print("robert")
#單項選擇
if is_nice:
    print("他人不錯")
# Out:
# robert

# %%
is_nice:bool = True
print("robert")
#雙向選擇
if is_nice:
    print("他人不錯")
else:
    print("它一般般")
# Out:
# robert
# 他人不錯

# %%
#成績判斷
scores = 85

if scores >= 60:
    print("及格")
else:
    print("不及格")
# Out:
# 及格

# %%
#成績判斷
scores = 95

if scores >= 90:
    print("優等")
elif scores >= 80:
    print("良好")
elif scores >= 70:
    print("中等")
else:
    print("需要努力")
# Out:
# 優等
